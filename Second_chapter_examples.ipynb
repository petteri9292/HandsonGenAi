# %%
from transformers import AutoTokenizer

prompt = "It was a dark and stormy"
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2-0.5B")
input_ids = tokenizer(prompt)["input_ids"]
print(input_ids)
# Out:
# [2132, 572, 264, 6319, 323, 13458, 88]

# %%
for token in input_ids:
    print(token, "\t:", tokenizer.decode(token))
# Out:
# 2132 	: It
# 572 	:  was
# 264 	:  a
# 6319 	:  dark
# 323 	:  and
# 13458 	:  storm
# 88 	: y

# %%
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2-0.5B")
# Out:
# config.json:   0%|          | 0.00/661 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]

# %%
input_ids = tokenizer(prompt,return_tensors="pt")["input_ids"]

outputs = model(input_ids)

# %%
print(outputs.logits.shape)

final_logits = outputs.logits[0,-1]
# Out:
# torch.Size([1, 7, 151936])

# %%
tokenizer.decode(final_logits.argmax())
# Out:
# ' night'

# %%
import torch

top10_logits = torch.topk(final_logits,10)

for index in top10_logits.indices:
    print(tokenizer.decode(index))
# Out:
#  night
#  evening
#  day
#  morning
#  winter
#  afternoon
#  Saturday
#  Sunday
#  Friday
#  October

# %%
top10 = torch.topk(final_logits.softmax(dim=0),10)

for value,index in zip(top10.values,top10_logits.indices):
    print(tokenizer.decode(index),value.item())
# Out:
#  night 0.88706374168396
#  evening 0.04300227761268616
#  day 0.02191721275448799
#  morning 0.004866069182753563
#  winter 0.00449405238032341
#  afternoon 0.0027222216594964266
#  Saturday 0.002517268992960453
#  Sunday 0.0018722137901932001
#  Friday 0.0017145765013992786
#  October 0.0016489927656948566

# %%
output_ids = model.generate(input_ids, max_new_tokens = 100)
decoded_text = tokenizer.decode(output_ids[0]) #Greedy decoding
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.

# %%
print(decoded_text)
# Out:
# It was a dark and stormy night. The sky was dark and the wind was howling. The rain was pouring down and the lightning was flashing. The sky was dark and the wind was howling. The rain was pouring down and the lightning was flashing. The sky was dark and the wind was howling. The rain was pouring down and the lightning was flashing. The sky was dark and the wind was howling. The rain was pouring down and the lightning was flashing. The sky was dark and the wind was howling

# %%
beam_output = model.generate( 
    input_ids,
    max_new_tokens = 30,
    num_beams=5
) #Beam decoding


decoded_text = tokenizer.decode(beam_output[0]) #Greedy decoding
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.

# %%
print(decoded_text)
# Out:
# It was a dark and stormy night. The wind was howling, and the rain was pouring down. The sky was dark and gloomy, and the air was filled with the

# %%
beam_output = model.generate( 
    input_ids,
    max_new_tokens = 1000,
    num_beams=5,
    repetition_penalty = 2.0
) #Beam decoding


decoded_text = tokenizer.decode(beam_output[0])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.

# %%
print(decoded_text)
# Out:
# It was a dark and stormy night. The sky was filled with thunder and lightning, and the wind howled in the distance. It was raining cats and dogs, and the streets were covered in puddles of water.
#
# As I walked down the street, I noticed a group of children playing in the rain. They were laughing and having fun, but I couldn't help but feel a sense of unease creeping up on me.
#
# Suddenly, I heard a loud noise coming from behind me. I turned around to see a man with a gun pointing his weapon at me. My heart raced as I realized what was happening.
#
# "What are you doing out here?" he asked, his voice low and menacing.
#
# "I don't know what you're talking about," I said, trying to keep my voice steady. "I'm just walking down the street."
#
# The man raised his gun and pointed it at me again. "You'll pay for what you've done," he said, his voice dripping with venom.
#
# I took a deep breath and tried to remain calm. "I didn't do anything wrong," I said. "I was just walking down the street."
#
# The man shook his head. "You're lying," he said. "You're not telling the truth. You're hiding something."
#
# I could feel my heart pounding in my chest. "I'm not hiding anything," I said. "I'm just walking down the street."
#
# The man's eyes narrowed. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's face twisted into a sneer. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything," I said again. "I'm just walking down the street."
#
# The man's eyes narrowed even further. "You're lying," he said again. "You're not telling the truth. You're hiding something."
#
# I took another deep breath and tried to stay calm. "I'm not hiding anything,"

# %%
output_sample = model.generate( 
    input_ids,
    max_new_tokens = 38,
    do_sample=True,
    top_k = 0
) 
decoded_text = tokenizer.decode(output_sample[0]) 
print(decoded_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# It was a dark and stormy night, like any typical warm, rainy, night with plenty of raindrops falling.I couldn't see clearly because I was sitting really close to Tiffany and it was raining hard. Nonetheless that made

# %%
output_sample = model.generate( 
    input_ids,
    max_new_tokens = 100,
    do_sample=True,
    top_k = 0,
    temperature = 1
) 
decoded_text = tokenizer.decode(output_sample[0]) 
print(decoded_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# It was a dark and stormy morning as Naomi Earp got ready for an early day at the California State University at Rio Costa. She had no worries that the day would be spent in class, plowing through dozens of assigned reading assignments, accomplished the work she had bought at the Cyberspace Computer Museum in Tangmere, and also spent most of the morning in a different place, a rough circle of grassland on the edge of her athletic field. entry in December 1913. After a few curious generations of

# %%
tokenizer.encode(" positive"),tokenizer.encode(" negative")


def score(review):
    prompt = f"""Question: Is the following review positive or negative about the movie? 
    Review: {review} Answer:"""

    input_ids = tokenizer(prompt,return_tensors="pt").input_ids
    final_logits = model(input_ids).logits[0,-1][[6785,8225]]
    if final_logits[0] > final_logits[1]:
        print("Positive")
        print(final_logits.softmax(dim=0))
    else:
        print("Negative")
        print(final_logits.softmax(dim=0))

# %%
score("This movie is the bomb!")

score("This movie bombed")

score("This movie blew me away with how good the ending was")
# Out:
# Positive
# tensor([0.5675, 0.4325], grad_fn=<SoftmaxBackward0>)
# Negative
# tensor([0.2045, 0.7955], grad_fn=<SoftmaxBackward0>)
# Negative
# tensor([0.2962, 0.7038], grad_fn=<SoftmaxBackward0>)

# %%
def translate(sentence):
    prompt = f"""\
    Translate English to Spanish:

    English: I dont not speak Spanish.
    Spanish: No hablo español.

    English: {sentence}
    Spanish:
    """

    inputs = tokenizer(prompt,return_tensors="pt").input_ids
    output = model.generate(inputs,
                            max_new_tokens = 15
                            )
    
    return tokenizer.decode(output[0])

# %%
print(translate("I like football"))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
#     Translate English to Spanish:
#
#     English: I dont not speak Spanish.
#     Spanish: No hablo español.
#
#     English: I like football
#     Spanish:
#      "Me gusta el fútbol"
#
#     English: I like to

# %%
from transformers import pipeline

fill_masker = pipeline("fill-mask", model="bert-base-uncased")
fill_masker("The [MASK] is made of milk.")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# c:\Users\Pette\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Pette\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Device set to use cuda:0
# [{'score': 0.19546672701835632,
#   'token': 9841,
#   'token_str': 'dish',
#   'sequence': 'the dish is made of milk.'},
#  {'score': 0.1290750503540039,
#   'token': 8808,
#   'token_str': 'cheese',
#   'sequence': 'the cheese is made of milk.'},
#  {'score': 0.1059066578745842,
#   'token': 6501,
#   'token_str': 'milk',
#   'sequence': 'the milk is made of milk.'},
#  {'score': 0.04112076386809349,
#   'token': 4392,
#   'token_str': 'drink',
#   'sequence': 'the drink is made of milk.'},
#  {'score': 0.037123341113328934,
#   'token': 7852,
#   'token_str': 'bread',
#   'sequence': 'the bread is made of milk.'}]

# %%
classifier = pipeline("text-classification", model="tabularisai/multilingual-sentiment-analysis")
classifier("This movie blew me away with how good it was")
# Out:
# Device set to use cuda:0
# [{'label': 'Positive', 'score': 0.5673620700836182}]

# %%
# !pip uninstall genaibook
# !pip install genaibook
# Out:
# ^C
# Requirement already satisfied: genaibook in c:\users\pette\anaconda3\lib\site-packages (0.0.4)
# Requirement already satisfied: accelerate in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (1.10.1)
# Requirement already satisfied: sentencepiece in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (0.2.1)
# Requirement already satisfied: fastcore in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (1.8.8)
# Requirement already satisfied: pandas in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (2.2.3)
# Requirement already satisfied: torch in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (2.6.0+cu124)
# Requirement already satisfied: torchvision in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (0.21.0+cu124)
# Requirement already satisfied: torchaudio in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (2.6.0+cu124)
# Requirement already satisfied: torchsummary in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (1.5.1)
# Requirement already satisfied: pillow in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (3.10.0)
# Requirement already satisfied: numpy in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (2.1.3)
# Requirement already satisfied: scipy in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (1.15.3)
# Requirement already satisfied: librosa in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (0.11.0)
# Requirement already satisfied: diffusers in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (0.35.1)
# Requirement already satisfied: transformers in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (4.56.0)
# Requirement already satisfied: sentence-transformers in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (5.1.0)
# Requirement already satisfied: bitsandbytes in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (0.47.0)
# Requirement already satisfied: datasets[audio] in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (3.6.0)
# Requirement already satisfied: jiwer in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (4.0.0)
# Requirement already satisfied: evaluate in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (0.4.5)
# Requirement already satisfied: pydub in c:\users\pette\anaconda3\lib\site-packages (from genaibook) (0.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\pette\appdata\roaming\python\python313\site-packages (from accelerate->genaibook) (25.0)
# Requirement already satisfied: psutil in c:\users\pette\appdata\roaming\python\python313\site-packages (from accelerate->genaibook) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\pette\anaconda3\lib\site-packages (from accelerate->genaibook) (6.0.2)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\pette\anaconda3\lib\site-packages (from accelerate->genaibook) (0.34.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\pette\anaconda3\lib\site-packages (from accelerate->genaibook) (0.6.2)
# Requirement already satisfied: filelock in c:\users\pette\anaconda3\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\pette\anaconda3\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (2025.3.0)
# Requirement already satisfied: requests in c:\users\pette\anaconda3\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\pette\anaconda3\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pette\anaconda3\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (4.12.2)
# Requirement already satisfied: networkx in c:\users\pette\anaconda3\lib\site-packages (from torch->genaibook) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\pette\anaconda3\lib\site-packages (from torch->genaibook) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\pette\anaconda3\lib\site-packages (from torch->genaibook) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\pette\anaconda3\lib\site-packages (from torch->genaibook) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\pette\anaconda3\lib\site-packages (from sympy==1.13.1->torch->genaibook) (1.3.0)
# Requirement already satisfied: colorama in c:\users\pette\appdata\roaming\python\python313\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate->genaibook) (0.4.6)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\pette\anaconda3\lib\site-packages (from datasets[audio]->genaibook) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\pette\anaconda3\lib\site-packages (from datasets[audio]->genaibook) (0.3.8)
# Requirement already satisfied: xxhash in c:\users\pette\anaconda3\lib\site-packages (from datasets[audio]->genaibook) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\pette\anaconda3\lib\site-packages (from datasets[audio]->genaibook) (0.70.16)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\pette\anaconda3\lib\site-packages (from datasets[audio]->genaibook) (0.13.1)
# Requirement already satisfied: soxr>=0.4.0 in c:\users\pette\anaconda3\lib\site-packages (from datasets[audio]->genaibook) (0.5.0.post1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\pette\anaconda3\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (3.11.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\pette\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\pette\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\pette\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\pette\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\pette\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\pette\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\pette\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (1.18.0)
# Requirement already satisfied: idna>=2.0 in c:\users\pette\anaconda3\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets[audio]->genaibook) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pette\anaconda3\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate->genaibook) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pette\anaconda3\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate->genaibook) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pette\anaconda3\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate->genaibook) (2025.4.26)
# Requirement already satisfied: cffi>=1.0 in c:\users\pette\anaconda3\lib\site-packages (from soundfile>=0.12.1->datasets[audio]->genaibook) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\pette\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]->genaibook) (2.21)
# Requirement already satisfied: importlib_metadata in c:\users\pette\anaconda3\lib\site-packages (from diffusers->genaibook) (8.5.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\pette\anaconda3\lib\site-packages (from diffusers->genaibook) (2024.11.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\pette\anaconda3\lib\site-packages (from importlib_metadata->diffusers->genaibook) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pette\anaconda3\lib\site-packages (from jinja2->torch->genaibook) (3.0.2)
# Requirement already satisfied: click>=8.1.8 in c:\users\pette\anaconda3\lib\site-packages (from jiwer->genaibook) (8.1.8)
# Requirement already satisfied: rapidfuzz>=3.9.7 in c:\users\pette\anaconda3\lib\site-packages (from jiwer->genaibook) (3.14.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (0.61.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\pette\appdata\roaming\python\python313\site-packages (from librosa->genaibook) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (1.8.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (1.0.3)
# Requirement already satisfied: standard-aifc in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (3.13.0)
# Requirement already satisfied: standard-sunau in c:\users\pette\anaconda3\lib\site-packages (from librosa->genaibook) (3.13.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\pette\anaconda3\lib\site-packages (from numba>=0.51.0->librosa->genaibook) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\pette\appdata\roaming\python\python313\site-packages (from pooch>=1.1->librosa->genaibook) (4.3.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\pette\anaconda3\lib\site-packages (from scikit-learn>=1.1.0->librosa->genaibook) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pette\anaconda3\lib\site-packages (from matplotlib->genaibook) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\pette\anaconda3\lib\site-packages (from matplotlib->genaibook) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pette\anaconda3\lib\site-packages (from matplotlib->genaibook) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pette\anaconda3\lib\site-packages (from matplotlib->genaibook) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pette\anaconda3\lib\site-packages (from matplotlib->genaibook) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pette\appdata\roaming\python\python313\site-packages (from matplotlib->genaibook) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pette\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->genaibook) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pette\anaconda3\lib\site-packages (from pandas->genaibook) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pette\anaconda3\lib\site-packages (from pandas->genaibook) (2025.2)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\pette\anaconda3\lib\site-packages (from transformers->genaibook) (0.22.0)
# Requirement already satisfied: standard-chunk in c:\users\pette\anaconda3\lib\site-packages (from standard-aifc->librosa->genaibook) (3.13.0)
# Requirement already satisfied: audioop-lts in c:\users\pette\anaconda3\lib\site-packages (from standard-aifc->librosa->genaibook) (0.2.2)

# %%
import requests
from PIL import Image

from genaibook.core import SampleURL


url = SampleURL.CatExample

image = Image.open(requests.get(url,stream=True).raw)
image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       1 import requests
#       2 from PIL import Image
# ----> 4 from genaibook.core import SampleURL
#       7 url = SampleURL.CatExample
#       9 image = Image.open(requests.get(url,stream=True).raw)
#
# ImportError: cannot import name 'SampleURL' from 'genaibook.core' (c:\Users\Pette\anaconda3\Lib\site-packages\genaibook\core.py)

# %%
from transformers import pipeline
pipe = pipeline(
    "zero-shot-image-classification",
    model="openai/clip-vit-base-patch32"


)


labels = ["cat","dog","zebra","feline"]
# Out:
# None

# %%
print(pipe(image,candidate=labels))
image
